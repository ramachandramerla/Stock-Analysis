# %%
#import the necessary modules
#import the data reader for get the data from the yahoo finance
from pandas_datareader import data , wb
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
# %matplotlib inline

# %%
import yfinance as yf

# %%
df1 = yf.Ticker("ITC.NS")

# %%
df1.info
# Out:
# {'address1': 'Virginia House',
#  'address2': '37 Jawaharlal Nehru Road',
#  'city': 'Kolkata',
#  'zip': '700071',
#  'country': 'India',
#  'phone': '91 33 2288 9371',
#  'fax': '91 33 2288 0655',
#  'website': 'https://www.itcportal.com',
#  'industry': 'Tobacco',
#  'industryKey': 'tobacco',
#  'industryDisp': 'Tobacco',
#  'sector': 'Consumer Defensive',
#  'sectorKey': 'consumer-defensive',
#  'sectorDisp': 'Consumer Defensive',
# ...

# %%
df=df1.history(period='max')
df.head()
# Out:
#                                Open      High       Low     Close    Volume  \
# Date
# 1996-01-01 00:00:00+05:30  3.236300  3.265455  3.226581  3.255737    985500
# 1996-01-02 00:00:00+05:30  3.187706  3.246017  3.084040  3.132633   7470000
# 1996-01-03 00:00:00+05:30  2.993334  3.063956  2.974544  3.032208  15160500
# 1996-01-04 00:00:00+05:30  3.032208  3.109309  2.999812  3.089223  12397500
# 1996-01-05 00:00:00+05:30  3.089224  3.077562  3.025729  3.033504   5008500
#
#                            Dividends  Stock Splits
# Date
# 1996-01-01 00:00:00+05:30        0.0           0.0
# 1996-01-02 00:00:00+05:30        0.0           0.0
# 1996-01-03 00:00:00+05:30        0.0           0.0
# 1996-01-04 00:00:00+05:30        0.0           0.0
# 1996-01-05 00:00:00+05:30        0.0           0.0

# %%
df=pd.DataFrame(df)

# %%
df.drop('Dividends',axis=1)
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1996-01-01 00:00:00+05:30    3.236300    3.265455    3.226581    3.255737
# 1996-01-02 00:00:00+05:30    3.187706    3.246017    3.084040    3.132633
# 1996-01-03 00:00:00+05:30    2.993334    3.063956    2.974544    3.032208
# 1996-01-04 00:00:00+05:30    3.032208    3.109309    2.999812    3.089223
# 1996-01-05 00:00:00+05:30    3.089224    3.077562    3.025729    3.033504
# ...                               ...         ...         ...         ...
# 2024-05-27 00:00:00+05:30  438.799988  438.899994  430.700012  431.500000
# 2024-05-28 00:00:00+05:30  432.100006  432.500000  428.250000  429.000000
# 2024-05-29 00:00:00+05:30  425.500000  432.399994  425.500000  430.950012
# 2024-05-30 00:00:00+05:30  428.500000  430.950012  422.350006  423.850006
# 2024-05-31 00:00:00+05:30  426.750000  429.549988  424.250000  426.450012
#
#                              Volume  Stock Splits
# Date
# ...

# %%
df=df.drop('Stock Splits',axis=1)

# %%
df=df.drop('Dividends',axis=1)

# %%
df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1996-01-01 00:00:00+05:30    3.236300    3.265455    3.226581    3.255737
# 1996-01-02 00:00:00+05:30    3.187706    3.246017    3.084040    3.132633
# 1996-01-03 00:00:00+05:30    2.993334    3.063956    2.974544    3.032208
# 1996-01-04 00:00:00+05:30    3.032208    3.109309    2.999812    3.089223
# 1996-01-05 00:00:00+05:30    3.089224    3.077562    3.025729    3.033504
# ...                               ...         ...         ...         ...
# 2024-05-27 00:00:00+05:30  438.799988  438.899994  430.700012  431.500000
# 2024-05-28 00:00:00+05:30  432.100006  432.500000  428.250000  429.000000
# 2024-05-29 00:00:00+05:30  425.500000  432.399994  425.500000  430.950012
# 2024-05-30 00:00:00+05:30  428.500000  430.950012  422.350006  423.850006
# 2024-05-31 00:00:00+05:30  426.750000  429.549988  424.250000  426.450012
#
#                              Volume
# Date
# ...

# %%
df.reset_index()
# Out:
#                           Date        Open        High         Low  \
# 0    1996-01-01 00:00:00+05:30    3.236300    3.265455    3.226581
# 1    1996-01-02 00:00:00+05:30    3.187706    3.246017    3.084040
# 2    1996-01-03 00:00:00+05:30    2.993334    3.063956    2.974544
# 3    1996-01-04 00:00:00+05:30    3.032208    3.109309    2.999812
# 4    1996-01-05 00:00:00+05:30    3.089224    3.077562    3.025729
# ...                        ...         ...         ...         ...
# 7131 2024-05-27 00:00:00+05:30  438.799988  438.899994  430.700012
# 7132 2024-05-28 00:00:00+05:30  432.100006  432.500000  428.250000
# 7133 2024-05-29 00:00:00+05:30  425.500000  432.399994  425.500000
# 7134 2024-05-30 00:00:00+05:30  428.500000  430.950012  422.350006
# 7135 2024-05-31 00:00:00+05:30  426.750000  429.549988  424.250000
#
#            Close    Volume
# 0       3.255737    985500
# 1       3.132633   7470000
# 2       3.032208  15160500
# 3       3.089223  12397500
# ...

# %%
df1=pd.DataFrame(df)

# %%
df1.reset_index(inplace=True)

# %%
df.iloc[0]
# Out:
# Open           3.236300
# High           3.265455
# Low            3.226581
# Close          3.255737
# Volume    985500.000000
# Name: 1996-01-01 00:00:00+05:30, dtype: float64

# %%
df1.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %%
df1.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %%
df1.dtypes
# Out:
# Date      datetime64[ns, Asia/Kolkata]
# Open                           float64
# High                           float64
# Low                            float64
# Close                          float64
# Volume                           int64
# dtype: object

# %%
df1['Date'].iloc[0]
# Out:
# Timestamp('1996-01-01 00:00:00+0530', tz='Asia/Kolkata')

# %%
df1['Date'].iloc[0]
# Out:
# Timestamp('1996-01-01 00:00:00+0530', tz='Asia/Kolkata')

# %%
import datetime

# %%
#converting the data to string as we have date and time stamp
df1['Date']=df1['Date'].map(str)

# %%
df1.dtypes
# Out:
# Date       object
# Open      float64
# High      float64
# Low       float64
# Close     float64
# Volume      int64
# dtype: object

# %%
df1['Date'].iloc[0]
# Out:
# '1996-01-01 00:00:00+05:30'

# %%
x=df1['Date'].iloc[0]
x.split(" ")[0]
# Out:
# '1996-01-01'

# %%
df1['Date-1']=df1['Date'].apply(lambda Date: Date.split(" ")[0])

# %%
df1.head(10)
# Out:
#                         Date      Open      High       Low     Close  \
# 0  1996-01-01 00:00:00+05:30  3.236300  3.265455  3.226581  3.255737
# 1  1996-01-02 00:00:00+05:30  3.187706  3.246017  3.084040  3.132633
# 2  1996-01-03 00:00:00+05:30  2.993334  3.063956  2.974544  3.032208
# 3  1996-01-04 00:00:00+05:30  3.032208  3.109309  2.999812  3.089223
# 4  1996-01-05 00:00:00+05:30  3.089224  3.077562  3.025729  3.033504
# 5  1996-01-08 00:00:00+05:30  3.033504  3.054884  2.922064  2.940205
# 6  1996-01-09 00:00:00+05:30  2.940206  2.979080  2.905867  2.932431
# 7  1996-01-10 00:00:00+05:30  2.932430  2.980376  2.902626  2.922712
# 8  1996-01-11 00:00:00+05:30  2.922712  2.940853  2.909105  2.938261
# 9  1996-01-12 00:00:00+05:30  2.938262  2.993334  2.928543  2.967417
#
#      Volume      Date-1
# 0    985500  1996-01-01
# 1   7470000  1996-01-02
# 2  15160500  1996-01-03
# 3  12397500  1996-01-04
# 4   5008500  1996-01-05
# 5  12645000  1996-01-08
# 6   8968500  1996-01-09
# ...

# %%
sns.pairplot(df1)
# Out:
# c:\Users\Ramachandra M\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Ramachandra M\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Ramachandra M\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
sns.boxplot(x='Date-1',)
# Out:
# c:\Users\Ramachandra M\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Close', ylabel='Density'>

# %%
df['Close'].plot.line(y='Close')
# Out:
# <Axes: xlabel='Date'>
